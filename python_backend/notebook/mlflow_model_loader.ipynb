# %%
# Out:
# True

# %%
import mlflow
import os
from dotenv import load_dotenv

load_dotenv()

mlflow.set_tracking_uri("https://dagshub.com/vanshsharma7832/ML-Learner.mlflow")

os.environ["MLFLOW_TRACKING_USERNAME"] = "vanshsharma7832"
os.environ["MLFLOW_TRACKING_PASSWORD"] = os.getenv("MLFLOW_TRACKING_PASSWORD")

model_uri = "models:/JobSimilarity/2"

path = mlflow.artifacts.download_artifacts(artifact_uri=model_uri, dst_path="models/job_similarity")

print(path)
# Out:
# ...
# C:\Users\vansh\AppData\Local\Temp\tmpvzogvj38\

# %%
print(os.getenv("MLFLOW_TRACKING_USERNAME"))
print(os.getenv("MLFLOW_TRACKING_PASSWORD"))
# Out:
# vanshsharma7832
# fee29b0c9f88f7918ad1474919b54153acd45f5e
